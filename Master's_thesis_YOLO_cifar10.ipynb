# %% [markdown]
# <a href="https://colab.research.google.com/github/FloAI/Thesis/blob/main/Master's_thesis_YOLO_cifar10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
13!pip install ultralytics
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n-cls.pt')  # load a pretrained model (recommended for training)

# Train the model
results = model.train(data='cifar10', epochs=25, imgsz=32)
# Out:
# ...
# Ultralytics YOLOv8.0.199 🚀 Python-3.10.12 torch-2.0.1+cu118 CPU (Intel Xeon 2.20GHz)
# ...

# %%
# %tensorboard --logdir logs
# Out:
# ---------------------------------------------------------------------------
# UsageError                                Traceback (most recent call last)
# <ipython-input-4-d46782f9619b> in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('tensorboard', '--logdir logs')
#
# /usr/local/lib/python3.10/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2396             extra = '' if cm is None else (' (But cell magic `%%%%%s` exists, '
#    2397                                     'did you mean that instead?)' % magic_name )
# -> 2398             raise UsageError(etpl % (magic_name, extra))
#    2399         else:
#    2400             # Note: this is the distance in the stack to the user's frame.
#
# UsageError: Line magic function `%tensorboard` not found.
